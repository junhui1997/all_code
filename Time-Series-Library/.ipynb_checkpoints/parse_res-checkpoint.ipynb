# %%
import re
file_path = 'result_classification2.txt'

with open(file_path, 'r') as file:
    lines = file.readlines()

def list2str(l):
    s = ''
    for ll in l:
        s+=ll
    return s
accuracies = []
models = []
elayers =[]
filters =[]
itrs = []
ids = []
seq_len = []
fcs = []
dls = []
for line in lines:
    if line.startswith('accuracy:'):
        accuracy = float(line.split(':')[1])
        accuracies.append(accuracy)
    if line.startswith('classification'):
        pattern_model = r'classification_bone_c_(.*?)_bone_drill_c'
        model = list2str(re.findall(pattern_model, ''.join(line)))
        
        pattern_elayer = r'el(\d+)_'
        elayer = list2str(re.findall(pattern_elayer, ''.join(line)))
        
        pattern_dlayer = r'dl(\d+)_'
        dl = list2str(re.findall(pattern_dlayer, ''.join(line)))
        
        pattern_seq = r'sl(\d+)_'
        seq = list2str(re.findall(pattern_seq, ''.join(line)))
        
        pattern_fc = r'fc(\d+)_eb'
        fc = list2str(re.findall(pattern_fc, ''.join(line)))
        
#         start_index = line.index("'Exp'") + len("'Exp'")
        start_index = line.index('Exp') + len('Exp')
        info = line[start_index+1:]
        filter_type = info.split('_')[0]
        itr = int(info.split('_')[-1])
        # 这个地方很奇怪，不知道后面还多了点啥，可能是空格
        ids.append(model+elayer+dl+filter_type+seq+'_'+fc)
        models.append(model)
        elayers.append(elayer)
        dls.append(dl)
        filters.append(filter_type)
        itrs.append(itr)
        seq_len.append(seq)
        fcs.append(fc)
        # print(line[:-5])
        #print(model,elayer,filter_type,itr)

#print('Accuracies:', accuracies)
print(len(accuracies),len(models),len(ids),)
# Out:
# 380 380 380

# %%
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

# %%
import pandas as pd
df = pd.DataFrame({"model": models,
                   "elayer": elayers,
                   'dlayer':dls,
                   "filter":filters,
                   "iter":itrs,
                   "acc":accuracies,
                   'id':ids,
                   'fc':fcs,
                   'seq_len':seq_len})
df
# Out:
#                          model elayer dlayer filter  iter       acc  \
# 0                   Autoformer      2      1   mean     0  0.483539
# 1                   Autoformer      2      1   mean     1  0.367908
# 2                   Autoformer      2      1   mean     2  0.376003
# 3                   Autoformer      2      1   mean     3  0.418025
# 4                   Autoformer      2      1   mean     4  0.403317
# 5                   Autoformer      2      1   mean     0  0.411934
# 6                   Autoformer      2      1   mean     1  0.387411
# 7                   Autoformer      2      1   mean     2  0.423321
# 8                   Autoformer      2      1   mean     3  0.460145
# 9                   Autoformer      2      1   mean     4  0.371017
# 10                  Autoformer      2      1   mean     0  0.409053
# 11                  Autoformer      2      1   mean     1  0.398050
# 12                  Autoformer      2      1   mean     2  0.402367
# 13                  Autoformer      2      1   mean     3  0.440217
# 14                  Autoformer      2      1   mean     4  0.385689
# 15                  Autoformer      2      1   mean     0  0.378601
# 16                  Autoformer      2      1   mean     1  0.357270
# 17                  Autoformer      2      1   mean     2  0.404903
# 18                  Autoformer      2      1   mean     3  0.413949
# 19                  Autoformer      2      1   mean     4  0.419721
# 20                 Transformer      2      1   mean     0  0.704527
# 21                 Transformer      2      1   mean     1  0.709663
# 22                 Transformer      2      1   mean     2  0.634136
# 23                 Transformer      2      1   mean     3  0.751359
# 24                 Transformer      2      1   mean     4  0.648625
# 25                 Transformer      2      1   mean     0  0.704527
# 26                 Transformer      2      1   mean     1  0.709663
# 27                 Transformer      2      1   mean     2  0.634136
# 28                 Transformer      2      1   mean     3  0.751359
# 29                 Transformer      2      1   mean     4  0.648625
# 30                 Transformer      2      1   mean     0  0.701235
# 31                 Transformer      2      1   mean     1  0.718972
# 32                 Transformer      2      1   mean     2  0.693998
# 33                 Transformer      2      1   mean     3  0.724638
# 34                 Transformer      2      1   mean     4  0.643979
# 35                 Transformer      2      1   mean     0  0.701235
# 36                 Transformer      2      1   mean     1  0.718972
# 37                 Transformer      2      1   mean     2  0.693998
# 38                 Transformer      2      1   mean     3  0.724638
# 39                 Transformer      2      1   mean     4  0.643979
# 40   Nonstationary_Transformer      2      1   mean     0  0.657202
# 41   Nonstationary_Transformer      2      1   mean     1  0.665780
# 42   Nonstationary_Transformer      2      1   mean     2  0.657372
# 43   Nonstationary_Transformer      2      1   mean     3  0.523098
# 44   Nonstationary_Transformer      2      1   mean     4  0.639459
# 45   Nonstationary_Transformer      2      1   mean     0  0.657202
# 46   Nonstationary_Transformer      2      1   mean     1  0.665780
# 47   Nonstationary_Transformer      2      1   mean     2  0.657372
# 48   Nonstationary_Transformer      2      1   mean     3  0.523098
# 49   Nonstationary_Transformer      2      1   mean     4  0.639459
# 50   Nonstationary_Transformer      2      1   mean     0  0.641975
# 51   Nonstationary_Transformer      2      1   mean     1  0.679965
# 52   Nonstationary_Transformer      2      1   mean     2  0.700761
# 53   Nonstationary_Transformer      2      1   mean     3  0.697464
# 54   Nonstationary_Transformer      2      1   mean     4  0.577661
# 55   Nonstationary_Transformer      2      1   mean     0  0.641975
# 56   Nonstationary_Transformer      2      1   mean     1  0.679965
# 57   Nonstationary_Transformer      2      1   mean     2  0.700761
# 58   Nonstationary_Transformer      2      1   mean     3  0.697464
# 59   Nonstationary_Transformer      2      1   mean     4  0.577661
# 60                     DLinear      2      1   mean     0  0.711523
# 61                     DLinear      2      1   mean     1  0.617021
# 62                     DLinear      2      1   mean     2  0.650190
# 63                     DLinear      2      1   mean     3  0.575181
# 64                     DLinear      2      1   mean     4  0.633784
# 65                     DLinear      2      1   mean     0  0.711523
# 66                     DLinear      2      1   mean     1  0.617021
# 67                     DLinear      2      1   mean     2  0.650190
# 68                     DLinear      2      1   mean     3  0.575181
# 69                     DLinear      2      1   mean     4  0.633784
# 70                     DLinear      2      1   mean     0  0.687243
# 71                     DLinear      2      1   mean     1  0.634752
# 72                     DLinear      2      1   mean     2  0.617921
# 73                     DLinear      2      1   mean     3  0.576087
# 74                     DLinear      2      1   mean     4  0.635253
# 75                     DLinear      2      1   mean     0  0.687243
# 76                     DLinear      2      1   mean     1  0.634752
# 77                     DLinear      2      1   mean     2  0.617921
# 78                     DLinear      2      1   mean     3  0.576087
# 79                     DLinear      2      1   mean     4  0.635253
# 80                   FEDformer      2      1   mean     0  0.356790
# 81                   FEDformer      2      1   mean     1  0.421099
# 82                   FEDformer      2      1   mean     2  0.413181
# 83                   FEDformer      2      1   mean     3  0.482790
# 84                   FEDformer      2      1   mean     4  0.653426
# 85                   FEDformer      2      1   mean     0  0.356790
# 86                   FEDformer      2      1   mean     1  0.421099
# 87                   FEDformer      2      1   mean     2  0.413181
# 88                   FEDformer      2      1   mean     3  0.482790
# 89                   FEDformer      2      1   mean     4  0.646879
# 90                   FEDformer      2      1   mean     0  0.245267
# 91                   FEDformer      2      1   mean     1  0.408688
# 92                   FEDformer      2      1   mean     2  0.662722
# 93                   FEDformer      2      1   mean     3  0.411232
# 94                   FEDformer      2      1   mean     4  0.359511
# 95                   FEDformer      2      1   mean     0  0.245267
# 96                   FEDformer      2      1   mean     1  0.408688
# 97                   FEDformer      2      1   mean     2  0.661031
# 98                   FEDformer      2      1   mean     3  0.411232
# 99                   FEDformer      2      1   mean     4  0.359511
# 100                   Informer      2      1   mean     0  0.669959
# 101                   Informer      2      1   mean     1  0.691489
# 102                   Informer      2      1   mean     2  0.703845
# 103                   Informer      2      1   mean     3  0.646739
# 104                   Informer      2      1   mean     4  0.668267
# 105                   Informer      2      1   mean     0  0.699177
# 106                   Informer      2      1   mean     1  0.703457
# 107                   Informer      2      1   mean     2  0.696662
# 108                   Informer      2      1   mean     3  0.627717
# 109                   Informer      2      1   mean     4  0.664775
# 110                   Informer      2      1   mean     0  0.748971
# 111                   Informer      2      1   mean     1  0.710106
# 112                   Informer      2      1   mean     2  0.721893
# 113                   Informer      2      1   mean     3  0.714674
# 114                   Informer      2      1   mean     4  0.677138
# 115                   Informer      2      1   mean     0  0.728395
# 116                   Informer      2      1   mean     1  0.703014
# 117                   Informer      2      1   mean     2  0.695689
# 118                   Informer      2      1   mean     3  0.736413
# 119                   Informer      2      1   mean     4  0.687609
# 120                   Reformer      2      1   mean     0  0.705350
# 121                   Reformer      2      1   mean     1  0.699911
# 122                   Reformer      2      1   mean     2  0.719054
# 123                   Reformer      2      1   mean     3  0.688859
# 124                   Reformer      2      1   mean     4  0.626364
# 125                   Reformer      2      1   mean     0  0.706584
# 126                   Reformer      2      1   mean     1  0.705230
# 127                   Reformer      2      1   mean     2  0.712717
# 128                   Reformer      2      1   mean     3  0.667572
# 129                   Reformer      2      1   mean     4  0.647752
# 130                   Reformer      2      1   mean     0  0.716049
# 131                   Reformer      2      1   mean     1  0.690603
# 132                   Reformer      2      1   mean     2  0.700761
# 133                   Reformer      2      1   mean     3  0.723732
# 134                   Reformer      2      1   mean     4  0.642234
# 135                   Reformer      2      1   mean     0  0.729218
# 136                   Reformer      2      1   mean     1  0.710106
# 137                   Reformer      2      1   mean     2  0.726965
# 138                   Reformer      2      1   mean     3  0.691123
# 139                   Reformer      2      1   mean     4  0.654450
# 140                   PatchTST      2      1   mean     0  0.362963
# 141                   PatchTST      2      1   mean     1  0.351064
# 142                   PatchTST      2      1   mean     2  0.359949
# 143                   PatchTST      2      1   mean     3  0.406250
# 144                   PatchTST      2      1   mean     4  0.368835
# 145                   PatchTST      2      1   mean     0  0.347325
# 146                   PatchTST      2      1   mean     1  0.345301
# 147                   PatchTST      2      1   mean     2  0.408112
# 148                   PatchTST      2      1   mean     3  0.368207
# 149                   PatchTST      2      1   mean     4  0.377128
# 150                   PatchTST      2      1   mean     0  0.334156
# 151                   PatchTST      2      1   mean     1  0.351064
# 152                   PatchTST      2      1   mean     2  0.364328
# 153                   PatchTST      2      1   mean     3  0.359601
# 154                   PatchTST      2      1   mean     4  0.365620
# 155                   PatchTST      2      1   mean     0  0.344856
# 156                   PatchTST      2      1   mean     1  0.348404
# 157                   PatchTST      2      1   mean     2  0.364328
# 158                   PatchTST      2      1   mean     3  0.352355
# 159                   PatchTST      2      1   mean     4  0.350785
# 160                 Pyraformer      2      1   mean     0  0.691770
# 161                 Pyraformer      2      1   mean     1  0.676862
# 162                 Pyraformer      2      1   mean     2  0.706379
# 163                 Pyraformer      2      1   mean     3  0.629076
# 164                 Pyraformer      2      1   mean     4  0.612833
# 165                 Pyraformer      2      1   mean     0  0.699177
# 166                 Pyraformer      2      1   mean     1  0.673316
# 167                 Pyraformer      2      1   mean     2  0.678496
# 168                 Pyraformer      2      1   mean     3  0.627717
# 169                 Pyraformer      2      1   mean     4  0.636840
# 170                 Pyraformer      2      1   mean     0  0.754733
# 171                 Pyraformer      2      1   mean     1  0.726950
# 172                 Pyraformer      2      1   mean     2  0.693153
# 173                 Pyraformer      2      1   mean     3  0.638587
# 174                 Pyraformer      2      1   mean     4  0.594241
# 175                 Pyraformer      2      1   mean     0  0.720165
# 176                 Pyraformer      2      1   mean     1  0.673759
# 177                 Pyraformer      2      1   mean     2  0.721048
# 178                 Pyraformer      2      1   mean     3  0.671196
# 179                 Pyraformer      2      1   mean     4  0.608202
# 180                Crossformer      2      1   mean     0  0.675720
# 181                Crossformer      2      1   mean     1  0.516844
# 182                Crossformer      2      1   mean     2  0.585129
# 183                Crossformer      2      1   mean     3  0.668931
# 184                Crossformer      2      1   mean     4  0.587953
# 185                Crossformer      2      1   mean     0  0.721811
# 186                Crossformer      2      1   mean     1  0.600621
# 187                Crossformer      2      1   mean     2  0.607098
# 188                Crossformer      2      1   mean     3  0.694293
# 189                Crossformer      2      1   mean     4  0.617198
# 190                Crossformer      2      1   mean     0  0.687243
# 191                Crossformer      2      1   mean     1  0.648050
# 192                Crossformer      2      1   mean     2  0.584108
# 193                Crossformer      2      1   mean     3  0.681159
# 194                Crossformer      2      1   mean     4  0.603839
# 195                Crossformer      2      1   mean     0  0.725103
# 196                Crossformer      2      1   mean     1  0.652482
# 197                Crossformer      2      1   mean     2  0.619611
# 198                Crossformer      2      1   mean     3  0.672101
# 199                Crossformer      2      1   mean     4  0.616928
# 200                       lstm      2      1   mean     0  0.630041
# 201                       lstm      2      1   mean     1  0.710106
# 202                       lstm      2      1   mean     2  0.687790
# 203                       lstm      2      1   mean     3  0.666667
# 204                       lstm      2      1   mean     4  0.605412
# 205                       lstm      2      1   mean     0  0.630041
# 206                       lstm      2      1   mean     1  0.710106
# 207                       lstm      2      1   mean     2  0.687790
# 208                       lstm      2      1   mean     3  0.666667
# 209                       lstm      2      1   mean     4  0.605412
# 210                       lstm      2      1   mean     0  0.709465
# 211                       lstm      2      1   mean     1  0.712766
# 212                       lstm      2      1   mean     2  0.707523
# 213                       lstm      2      1   mean     3  0.673913
# 214                       lstm      2      1   mean     4  0.622164
# 215                       lstm      2      1   mean     0  0.709465
# 216                       lstm      2      1   mean     1  0.712766
# 217                       lstm      2      1   mean     2  0.707523
# 218                       lstm      2      1   mean     3  0.673913
# 219                       lstm      2      1   mean     4  0.622164
# 220                   conv_net      2      1   mean     0  0.692593
# 221                   conv_net      2      1   mean     1  0.699468
# 222                   conv_net      2      1   mean     2  0.696662
# 223                   conv_net      2      1   mean     3  0.704257
# 224                   conv_net      2      1   mean     4  0.635094
# 225                   conv_net      2      1   mean     0  0.692593
# 226                   conv_net      2      1   mean     1  0.699468
# 227                   conv_net      2      1   mean     2  0.696662
# 228                   conv_net      2      1   mean     3  0.704257
# 229                   conv_net      2      1   mean     4  0.632475
# 230                   conv_net      2      1   mean     0  0.704527
# 231                   conv_net      2      1   mean     1  0.741135
# 232                   conv_net      2      1   mean     2  0.721048
# 233                   conv_net      2      1   mean     3  0.746377
# 234                   conv_net      2      1   mean     4  0.603839
# 235                   conv_net      2      1   mean     0  0.703704
# 236                   conv_net      2      1   mean     1  0.741135
# 237                   conv_net      2      1   mean     2  0.721048
# 238                   conv_net      2      1   mean     3  0.746377
# 239                   conv_net      2      1   mean     4  0.603839
# 240                         bp      2      1   mean     0  0.685597
# 241                         bp      2      1   mean     1  0.709220
# 242                         bp      2      1   mean     2  0.692015
# 243                         bp      2      1   mean     3  0.721467
# 244                         bp      2      1   mean     4  0.630729
# 245                         bp      2      1   mean     0  0.685597
# 246                         bp      2      1   mean     1  0.709220
# 247                         bp      2      1   mean     2  0.692015
# 248                         bp      2      1   mean     3  0.721467
# 249                         bp      2      1   mean     4  0.630729
# 250                         bp      2      1   mean     0  0.741564
# 251                         bp      2      1   mean     1  0.702128
# 252                         bp      2      1   mean     2  0.688926
# 253                         bp      2      1   mean     3  0.738225
# 254                         bp      2      1   mean     4  0.582024
# 255                         bp      2      1   mean     0  0.741564
# 256                         bp      2      1   mean     1  0.702128
# 257                         bp      2      1   mean     2  0.688926
# 258                         bp      2      1   mean     3  0.738225
# 259                         bp      2      1   mean     4  0.582024
# 260                   lstm_fcn      2      1   mean     0  0.731687
# 261                   lstm_fcn      2      1   mean     1  0.682181
# 262                   lstm_fcn      2      1   mean     2  0.699620
# 263                   lstm_fcn      2      1   mean     3  0.716938
# 264                   lstm_fcn      2      1   mean     4  0.633784
# 265                   lstm_fcn      2      1   mean     0  0.731687
# 266                   lstm_fcn      2      1   mean     1  0.682181
# 267                   lstm_fcn      2      1   mean     2  0.699620
# 268                   lstm_fcn      2      1   mean     3  0.716938
# 269                   lstm_fcn      2      1   mean     4  0.633784
# 270                   lstm_fcn      2      1   mean     0  0.721811
# 271                   lstm_fcn      2      1   mean     1  0.683511
# 272                   lstm_fcn      2      1   mean     2  0.691462
# 273                   lstm_fcn      2      1   mean     3  0.679348
# 274                   lstm_fcn      2      1   mean     4  0.636998
# 275                   lstm_fcn      2      1   mean     0  0.721811
# 276                   lstm_fcn      2      1   mean     1  0.683511
# 277                   lstm_fcn      2      1   mean     2  0.691462
# 278                   lstm_fcn      2      1   mean     3  0.679348
# 279                   lstm_fcn      2      1   mean     4  0.636998
# 280                        fcn      2      1   mean     0  0.695885
# 281                        fcn      2      1   mean     1  0.693262
# 282                        fcn      2      1   mean     2  0.696240
# 283                        fcn      2      1   mean     3  0.716486
# 284                        fcn      2      1   mean     4  0.615452
# 285                        fcn      2      1   mean     0  0.695885
# 286                        fcn      2      1   mean     1  0.693262
# 287                        fcn      2      1   mean     2  0.696240
# 288                        fcn      2      1   mean     3  0.716486
# 289                        fcn      2      1   mean     4  0.615452
# 290                        fcn      2      1   mean     0  0.718519
# 291                        fcn      2      1   mean     1  0.719858
# 292                        fcn      2      1   mean     2  0.690617
# 293                        fcn      2      1   mean     3  0.735507
# 294                        fcn      2      1   mean     4  0.638743
# 295                        fcn      2      1   mean     0  0.718519
# 296                        fcn      2      1   mean     1  0.719858
# 297                        fcn      2      1   mean     2  0.690617
# 298                        fcn      2      1   mean     3  0.735507
# 299                        fcn      2      1   mean     4  0.638743
# 300                      fcn_m      2      1   mean     0  0.688889
# 301                      fcn_m      2      1   mean     1  0.715869
# 302                      fcn_m      2      1   mean     2  0.685678
# 303                      fcn_m      2      1   mean     3  0.676178
# 304                      fcn_m      2      1   mean     4  0.642514
# 305                      fcn_m      2      1   mean     0  0.688889
# 306                      fcn_m      2      1   mean     1  0.715869
# 307                      fcn_m      2      1   mean     2  0.685678
# 308                      fcn_m      2      1   mean     3  0.676178
# 309                      fcn_m      2      1   mean     4  0.642514
# 310                      fcn_m      2      1   mean     0  0.724280
# 311                      fcn_m      2      1   mean     1  0.726950
# 312                      fcn_m      2      1   mean     2  0.677092
# 313                      fcn_m      2      1   mean     3  0.688406
# 314                      fcn_m      2      1   mean     4  0.607330
# 315                      fcn_m      2      1   mean     0  0.724280
# 316                      fcn_m      2      1   mean     1  0.726950
# 317                      fcn_m      2      1   mean     2  0.677092
# 318                      fcn_m      2      1   mean     3  0.688406
# 319                      fcn_m      2      1   mean     4  0.607330
# 320                  conv_next      2      1   mean     0  0.656790
# 321                  conv_next      2      1   mean     1  0.668883
# 322                  conv_next      2      1   mean     2  0.699620
# 323                  conv_next      2      1   mean     3  0.623641
# 324                  conv_next      2      1   mean     4  0.639022
# 325                  conv_next      2      1   mean     0  0.656790
# 326                  conv_next      2      1   mean     1  0.668883
# 327                  conv_next      2      1   mean     2  0.699620
# 328                  conv_next      2      1   mean     3  0.646739
# 329                  conv_next      2      1   mean     4  0.617198
# 330                  conv_next      2      1   mean     0  0.706996
# 331                  conv_next      2      1   mean     1  0.635638
# 332                  conv_next      2      1   mean     2  0.674556
# 333                  conv_next      2      1   mean     3  0.636775
# 334                  conv_next      2      1   mean     4  0.635253
# 335                  conv_next      2      1   mean     0  0.706996
# 336                  conv_next      2      1   mean     1  0.635638
# 337                  conv_next      2      1   mean     2  0.674556
# 338                  conv_next      2      1   mean     3  0.636775
# 339                  conv_next      2      1   mean     4  0.643106
# 340                   TimesNet      2      1   mean     0  0.702469
# 341                   TimesNet      2      1   mean     1  0.693262
# 342                   TimesNet      2      1   mean     2  0.668779
# 343                   TimesNet      2      1   mean     3  0.692029
# 344                   TimesNet      2      1   mean     4  0.621563
# 345                   TimesNet      2      1   mean     0  0.702469
# 346                   TimesNet      2      1   mean     1  0.696365
# 347                   TimesNet      2      1   mean     2  0.712294
# 348                   TimesNet      2      1   mean     3  0.648551
# 349                   TimesNet      2      1   mean     4  0.634657
# 350                   TimesNet      2      1   mean     0  0.709465
# 351                   TimesNet      2      1   mean     1  0.734929
# 352                   TimesNet      2      1   mean     2  0.708369
# 353                   TimesNet      2      1   mean     3  0.617754
# 354                   TimesNet      2      1   mean     4  0.628272
# 355                   TimesNet      2      1   mean     0  0.708642
# 356                   TimesNet      2      1   mean     1  0.734929
# 357                   TimesNet      2      1   mean     2  0.708369
# 358                   TimesNet      2      1   mean     3  0.617754
# 359                   TimesNet      2      1   mean     4  0.625654
# 360                         my      2      1   mean     0  0.665021
# 361                         my      2      1   mean     1  0.724734
# 362                         my      2      1   mean     2  0.651035
# 363                         my      2      1   mean     3  0.644928
# 364                         my      2      1   mean     4  0.612396
# 365                         my      2      1   mean     0  0.673663
# 366                         my      2      1   mean     1  0.717642
# 367                         my      2      1   mean     2  0.654837
# 368                         my      2      1   mean     3  0.668025
# 369                         my      2      1   mean     4  0.639022
# 370                         my      2      1   mean     0  0.717695
# 371                         my      2      1   mean     1  0.733156
# 372                         my      2      1   mean     2  0.658495
# 373                         my      2      1   mean     3  0.665761
# 374                         my      2      1   mean     4  0.658813
# 375                         my      2      1   mean     0  0.726749
# 376                         my      2      1   mean     1  0.709220
# 377                         my      2      1   mean     2  0.661031
# 378                         my      2      1   mean     3  0.702899
# 379                         my      2      1   mean     4  0.682373
#
#                                        id fc seq_len
# 0                   Autoformer21mean250_1  1     250
# 1                   Autoformer21mean250_1  1     250
# 2                   Autoformer21mean250_1  1     250
# 3                   Autoformer21mean250_1  1     250
# 4                   Autoformer21mean250_1  1     250
# 5                   Autoformer21mean250_2  2     250
# 6                   Autoformer21mean250_2  2     250
# 7                   Autoformer21mean250_2  2     250
# 8                   Autoformer21mean250_2  2     250
# 9                   Autoformer21mean250_2  2     250
# 10                  Autoformer21mean500_1  1     500
# 11                  Autoformer21mean500_1  1     500
# 12                  Autoformer21mean500_1  1     500
# 13                  Autoformer21mean500_1  1     500
# 14                  Autoformer21mean500_1  1     500
# 15                  Autoformer21mean500_2  2     500
# 16                  Autoformer21mean500_2  2     500
# 17                  Autoformer21mean500_2  2     500
# 18                  Autoformer21mean500_2  2     500
# 19                  Autoformer21mean500_2  2     500
# 20                 Transformer21mean250_1  1     250
# 21                 Transformer21mean250_1  1     250
# 22                 Transformer21mean250_1  1     250
# 23                 Transformer21mean250_1  1     250
# 24                 Transformer21mean250_1  1     250
# 25                 Transformer21mean250_2  2     250
# 26                 Transformer21mean250_2  2     250
# 27                 Transformer21mean250_2  2     250
# 28                 Transformer21mean250_2  2     250
# 29                 Transformer21mean250_2  2     250
# 30                 Transformer21mean500_1  1     500
# 31                 Transformer21mean500_1  1     500
# 32                 Transformer21mean500_1  1     500
# 33                 Transformer21mean500_1  1     500
# 34                 Transformer21mean500_1  1     500
# 35                 Transformer21mean500_2  2     500
# 36                 Transformer21mean500_2  2     500
# 37                 Transformer21mean500_2  2     500
# 38                 Transformer21mean500_2  2     500
# 39                 Transformer21mean500_2  2     500
# 40   Nonstationary_Transformer21mean250_1  1     250
# 41   Nonstationary_Transformer21mean250_1  1     250
# 42   Nonstationary_Transformer21mean250_1  1     250
# 43   Nonstationary_Transformer21mean250_1  1     250
# 44   Nonstationary_Transformer21mean250_1  1     250
# 45   Nonstationary_Transformer21mean250_2  2     250
# 46   Nonstationary_Transformer21mean250_2  2     250
# 47   Nonstationary_Transformer21mean250_2  2     250
# 48   Nonstationary_Transformer21mean250_2  2     250
# 49   Nonstationary_Transformer21mean250_2  2     250
# 50   Nonstationary_Transformer21mean500_1  1     500
# 51   Nonstationary_Transformer21mean500_1  1     500
# 52   Nonstationary_Transformer21mean500_1  1     500
# 53   Nonstationary_Transformer21mean500_1  1     500
# 54   Nonstationary_Transformer21mean500_1  1     500
# 55   Nonstationary_Transformer21mean500_2  2     500
# 56   Nonstationary_Transformer21mean500_2  2     500
# 57   Nonstationary_Transformer21mean500_2  2     500
# 58   Nonstationary_Transformer21mean500_2  2     500
# 59   Nonstationary_Transformer21mean500_2  2     500
# 60                     DLinear21mean250_1  1     250
# 61                     DLinear21mean250_1  1     250
# 62                     DLinear21mean250_1  1     250
# 63                     DLinear21mean250_1  1     250
# 64                     DLinear21mean250_1  1     250
# 65                     DLinear21mean250_2  2     250
# 66                     DLinear21mean250_2  2     250
# 67                     DLinear21mean250_2  2     250
# 68                     DLinear21mean250_2  2     250
# 69                     DLinear21mean250_2  2     250
# 70                     DLinear21mean500_1  1     500
# 71                     DLinear21mean500_1  1     500
# 72                     DLinear21mean500_1  1     500
# 73                     DLinear21mean500_1  1     500
# 74                     DLinear21mean500_1  1     500
# 75                     DLinear21mean500_2  2     500
# 76                     DLinear21mean500_2  2     500
# 77                     DLinear21mean500_2  2     500
# 78                     DLinear21mean500_2  2     500
# 79                     DLinear21mean500_2  2     500
# 80                   FEDformer21mean250_1  1     250
# 81                   FEDformer21mean250_1  1     250
# 82                   FEDformer21mean250_1  1     250
# 83                   FEDformer21mean250_1  1     250
# 84                   FEDformer21mean250_1  1     250
# 85                   FEDformer21mean250_2  2     250
# 86                   FEDformer21mean250_2  2     250
# 87                   FEDformer21mean250_2  2     250
# 88                   FEDformer21mean250_2  2     250
# 89                   FEDformer21mean250_2  2     250
# 90                   FEDformer21mean500_1  1     500
# 91                   FEDformer21mean500_1  1     500
# 92                   FEDformer21mean500_1  1     500
# 93                   FEDformer21mean500_1  1     500
# 94                   FEDformer21mean500_1  1     500
# 95                   FEDformer21mean500_2  2     500
# 96                   FEDformer21mean500_2  2     500
# 97                   FEDformer21mean500_2  2     500
# 98                   FEDformer21mean500_2  2     500
# 99                   FEDformer21mean500_2  2     500
# 100                   Informer21mean250_1  1     250
# 101                   Informer21mean250_1  1     250
# 102                   Informer21mean250_1  1     250
# 103                   Informer21mean250_1  1     250
# 104                   Informer21mean250_1  1     250
# 105                   Informer21mean250_2  2     250
# 106                   Informer21mean250_2  2     250
# 107                   Informer21mean250_2  2     250
# 108                   Informer21mean250_2  2     250
# 109                   Informer21mean250_2  2     250
# 110                   Informer21mean500_1  1     500
# 111                   Informer21mean500_1  1     500
# 112                   Informer21mean500_1  1     500
# 113                   Informer21mean500_1  1     500
# 114                   Informer21mean500_1  1     500
# 115                   Informer21mean500_2  2     500
# 116                   Informer21mean500_2  2     500
# 117                   Informer21mean500_2  2     500
# 118                   Informer21mean500_2  2     500
# 119                   Informer21mean500_2  2     500
# 120                   Reformer21mean250_1  1     250
# 121                   Reformer21mean250_1  1     250
# 122                   Reformer21mean250_1  1     250
# 123                   Reformer21mean250_1  1     250
# 124                   Reformer21mean250_1  1     250
# 125                   Reformer21mean250_2  2     250
# 126                   Reformer21mean250_2  2     250
# 127                   Reformer21mean250_2  2     250
# 128                   Reformer21mean250_2  2     250
# 129                   Reformer21mean250_2  2     250
# 130                   Reformer21mean500_1  1     500
# 131                   Reformer21mean500_1  1     500
# 132                   Reformer21mean500_1  1     500
# 133                   Reformer21mean500_1  1     500
# 134                   Reformer21mean500_1  1     500
# 135                   Reformer21mean500_2  2     500
# 136                   Reformer21mean500_2  2     500
# 137                   Reformer21mean500_2  2     500
# 138                   Reformer21mean500_2  2     500
# 139                   Reformer21mean500_2  2     500
# 140                   PatchTST21mean250_1  1     250
# 141                   PatchTST21mean250_1  1     250
# 142                   PatchTST21mean250_1  1     250
# 143                   PatchTST21mean250_1  1     250
# 144                   PatchTST21mean250_1  1     250
# 145                   PatchTST21mean250_2  2     250
# 146                   PatchTST21mean250_2  2     250
# 147                   PatchTST21mean250_2  2     250
# 148                   PatchTST21mean250_2  2     250
# 149                   PatchTST21mean250_2  2     250
# 150                   PatchTST21mean500_1  1     500
# 151                   PatchTST21mean500_1  1     500
# 152                   PatchTST21mean500_1  1     500
# 153                   PatchTST21mean500_1  1     500
# 154                   PatchTST21mean500_1  1     500
# 155                   PatchTST21mean500_2  2     500
# 156                   PatchTST21mean500_2  2     500
# 157                   PatchTST21mean500_2  2     500
# 158                   PatchTST21mean500_2  2     500
# 159                   PatchTST21mean500_2  2     500
# 160                 Pyraformer21mean250_1  1     250
# 161                 Pyraformer21mean250_1  1     250
# 162                 Pyraformer21mean250_1  1     250
# 163                 Pyraformer21mean250_1  1     250
# 164                 Pyraformer21mean250_1  1     250
# 165                 Pyraformer21mean250_2  2     250
# 166                 Pyraformer21mean250_2  2     250
# 167                 Pyraformer21mean250_2  2     250
# 168                 Pyraformer21mean250_2  2     250
# 169                 Pyraformer21mean250_2  2     250
# 170                 Pyraformer21mean500_1  1     500
# 171                 Pyraformer21mean500_1  1     500
# 172                 Pyraformer21mean500_1  1     500
# 173                 Pyraformer21mean500_1  1     500
# 174                 Pyraformer21mean500_1  1     500
# 175                 Pyraformer21mean500_2  2     500
# 176                 Pyraformer21mean500_2  2     500
# 177                 Pyraformer21mean500_2  2     500
# 178                 Pyraformer21mean500_2  2     500
# 179                 Pyraformer21mean500_2  2     500
# 180                Crossformer21mean250_1  1     250
# 181                Crossformer21mean250_1  1     250
# 182                Crossformer21mean250_1  1     250
# 183                Crossformer21mean250_1  1     250
# 184                Crossformer21mean250_1  1     250
# 185                Crossformer21mean250_2  2     250
# 186                Crossformer21mean250_2  2     250
# 187                Crossformer21mean250_2  2     250
# 188                Crossformer21mean250_2  2     250
# 189                Crossformer21mean250_2  2     250
# 190                Crossformer21mean500_1  1     500
# 191                Crossformer21mean500_1  1     500
# 192                Crossformer21mean500_1  1     500
# 193                Crossformer21mean500_1  1     500
# 194                Crossformer21mean500_1  1     500
# 195                Crossformer21mean500_2  2     500
# 196                Crossformer21mean500_2  2     500
# 197                Crossformer21mean500_2  2     500
# 198                Crossformer21mean500_2  2     500
# 199                Crossformer21mean500_2  2     500
# 200                       lstm21mean250_1  1     250
# 201                       lstm21mean250_1  1     250
# 202                       lstm21mean250_1  1     250
# 203                       lstm21mean250_1  1     250
# 204                       lstm21mean250_1  1     250
# 205                       lstm21mean250_2  2     250
# 206                       lstm21mean250_2  2     250
# 207                       lstm21mean250_2  2     250
# 208                       lstm21mean250_2  2     250
# 209                       lstm21mean250_2  2     250
# 210                       lstm21mean500_1  1     500
# 211                       lstm21mean500_1  1     500
# 212                       lstm21mean500_1  1     500
# 213                       lstm21mean500_1  1     500
# 214                       lstm21mean500_1  1     500
# 215                       lstm21mean500_2  2     500
# 216                       lstm21mean500_2  2     500
# 217                       lstm21mean500_2  2     500
# 218                       lstm21mean500_2  2     500
# 219                       lstm21mean500_2  2     500
# 220                   conv_net21mean250_1  1     250
# 221                   conv_net21mean250_1  1     250
# 222                   conv_net21mean250_1  1     250
# 223                   conv_net21mean250_1  1     250
# 224                   conv_net21mean250_1  1     250
# 225                   conv_net21mean250_2  2     250
# 226                   conv_net21mean250_2  2     250
# 227                   conv_net21mean250_2  2     250
# 228                   conv_net21mean250_2  2     250
# 229                   conv_net21mean250_2  2     250
# 230                   conv_net21mean500_1  1     500
# 231                   conv_net21mean500_1  1     500
# 232                   conv_net21mean500_1  1     500
# 233                   conv_net21mean500_1  1     500
# 234                   conv_net21mean500_1  1     500
# 235                   conv_net21mean500_2  2     500
# 236                   conv_net21mean500_2  2     500
# 237                   conv_net21mean500_2  2     500
# 238                   conv_net21mean500_2  2     500
# 239                   conv_net21mean500_2  2     500
# 240                         bp21mean250_1  1     250
# 241                         bp21mean250_1  1     250
# 242                         bp21mean250_1  1     250
# 243                         bp21mean250_1  1     250
# 244                         bp21mean250_1  1     250
# 245                         bp21mean250_2  2     250
# 246                         bp21mean250_2  2     250
# 247                         bp21mean250_2  2     250
# 248                         bp21mean250_2  2     250
# 249                         bp21mean250_2  2     250
# 250                         bp21mean500_1  1     500
# 251                         bp21mean500_1  1     500
# 252                         bp21mean500_1  1     500
# 253                         bp21mean500_1  1     500
# 254                         bp21mean500_1  1     500
# 255                         bp21mean500_2  2     500
# 256                         bp21mean500_2  2     500
# 257                         bp21mean500_2  2     500
# 258                         bp21mean500_2  2     500
# 259                         bp21mean500_2  2     500
# 260                   lstm_fcn21mean250_1  1     250
# 261                   lstm_fcn21mean250_1  1     250
# 262                   lstm_fcn21mean250_1  1     250
# 263                   lstm_fcn21mean250_1  1     250
# 264                   lstm_fcn21mean250_1  1     250
# 265                   lstm_fcn21mean250_2  2     250
# 266                   lstm_fcn21mean250_2  2     250
# 267                   lstm_fcn21mean250_2  2     250
# 268                   lstm_fcn21mean250_2  2     250
# 269                   lstm_fcn21mean250_2  2     250
# 270                   lstm_fcn21mean500_1  1     500
# 271                   lstm_fcn21mean500_1  1     500
# 272                   lstm_fcn21mean500_1  1     500
# 273                   lstm_fcn21mean500_1  1     500
# 274                   lstm_fcn21mean500_1  1     500
# 275                   lstm_fcn21mean500_2  2     500
# 276                   lstm_fcn21mean500_2  2     500
# 277                   lstm_fcn21mean500_2  2     500
# 278                   lstm_fcn21mean500_2  2     500
# 279                   lstm_fcn21mean500_2  2     500
# 280                        fcn21mean250_1  1     250
# 281                        fcn21mean250_1  1     250
# 282                        fcn21mean250_1  1     250
# 283                        fcn21mean250_1  1     250
# 284                        fcn21mean250_1  1     250
# 285                        fcn21mean250_2  2     250
# 286                        fcn21mean250_2  2     250
# 287                        fcn21mean250_2  2     250
# 288                        fcn21mean250_2  2     250
# 289                        fcn21mean250_2  2     250
# 290                        fcn21mean500_1  1     500
# 291                        fcn21mean500_1  1     500
# 292                        fcn21mean500_1  1     500
# 293                        fcn21mean500_1  1     500
# 294                        fcn21mean500_1  1     500
# 295                        fcn21mean500_2  2     500
# 296                        fcn21mean500_2  2     500
# 297                        fcn21mean500_2  2     500
# 298                        fcn21mean500_2  2     500
# 299                        fcn21mean500_2  2     500
# 300                      fcn_m21mean250_1  1     250
# 301                      fcn_m21mean250_1  1     250
# 302                      fcn_m21mean250_1  1     250
# 303                      fcn_m21mean250_1  1     250
# 304                      fcn_m21mean250_1  1     250
# 305                      fcn_m21mean250_2  2     250
# 306                      fcn_m21mean250_2  2     250
# 307                      fcn_m21mean250_2  2     250
# 308                      fcn_m21mean250_2  2     250
# 309                      fcn_m21mean250_2  2     250
# 310                      fcn_m21mean500_1  1     500
# 311                      fcn_m21mean500_1  1     500
# 312                      fcn_m21mean500_1  1     500
# 313                      fcn_m21mean500_1  1     500
# 314                      fcn_m21mean500_1  1     500
# 315                      fcn_m21mean500_2  2     500
# 316                      fcn_m21mean500_2  2     500
# 317                      fcn_m21mean500_2  2     500
# 318                      fcn_m21mean500_2  2     500
# 319                      fcn_m21mean500_2  2     500
# 320                  conv_next21mean250_1  1     250
# 321                  conv_next21mean250_1  1     250
# 322                  conv_next21mean250_1  1     250
# 323                  conv_next21mean250_1  1     250
# 324                  conv_next21mean250_1  1     250
# 325                  conv_next21mean250_2  2     250
# 326                  conv_next21mean250_2  2     250
# 327                  conv_next21mean250_2  2     250
# 328                  conv_next21mean250_2  2     250
# 329                  conv_next21mean250_2  2     250
# 330                  conv_next21mean500_1  1     500
# 331                  conv_next21mean500_1  1     500
# 332                  conv_next21mean500_1  1     500
# 333                  conv_next21mean500_1  1     500
# 334                  conv_next21mean500_1  1     500
# 335                  conv_next21mean500_2  2     500
# 336                  conv_next21mean500_2  2     500
# 337                  conv_next21mean500_2  2     500
# 338                  conv_next21mean500_2  2     500
# 339                  conv_next21mean500_2  2     500
# 340                   TimesNet21mean250_1  1     250
# 341                   TimesNet21mean250_1  1     250
# 342                   TimesNet21mean250_1  1     250
# 343                   TimesNet21mean250_1  1     250
# 344                   TimesNet21mean250_1  1     250
# 345                   TimesNet21mean250_2  2     250
# 346                   TimesNet21mean250_2  2     250
# 347                   TimesNet21mean250_2  2     250
# 348                   TimesNet21mean250_2  2     250
# 349                   TimesNet21mean250_2  2     250
# 350                   TimesNet21mean500_1  1     500
# 351                   TimesNet21mean500_1  1     500
# 352                   TimesNet21mean500_1  1     500
# 353                   TimesNet21mean500_1  1     500
# 354                   TimesNet21mean500_1  1     500
# 355                   TimesNet21mean500_2  2     500
# 356                   TimesNet21mean500_2  2     500
# 357                   TimesNet21mean500_2  2     500
# 358                   TimesNet21mean500_2  2     500
# 359                   TimesNet21mean500_2  2     500
# 360                         my21mean250_1  1     250
# 361                         my21mean250_1  1     250
# 362                         my21mean250_1  1     250
# 363                         my21mean250_1  1     250
# 364                         my21mean250_1  1     250
# 365                         my21mean250_2  2     250
# 366                         my21mean250_2  2     250
# 367                         my21mean250_2  2     250
# 368                         my21mean250_2  2     250
# 369                         my21mean250_2  2     250
# 370                         my21mean500_1  1     500
# 371                         my21mean500_1  1     500
# 372                         my21mean500_1  1     500
# 373                         my21mean500_1  1     500
# 374                         my21mean500_1  1     500
# 375                         my21mean500_2  2     500
# 376                         my21mean500_2  2     500
# 377                         my21mean500_2  2     500
# 378                         my21mean500_2  2     500
# 379                         my21mean500_2  2     500

# %%
# import pandas as pd

# # 创建示例DataFrame
# data = {'id': [1, 1, 1, 2, 2, 2],
#         'name': ['John', 'Alice', 'Tom', 'Mike', 'Sarah', 'Emily'],
#         'value': [10, 15, 12, 8, 7, 9]}
# df = pd.DataFrame(data)

# # 选择最后一个name，并对'value'列进行平均值计算
# df_avg = df.groupby('id').agg({'name': 'last', 'value': 'mean'}).reset_index()

# print(df_avg)

# %%
df_res = df.groupby('id').agg({'model': 'last',
                               'elayer': 'last',
                               'filter': 'last',
                               'seq_len':'last',
                               'dlayer':'last',
                               'fc':'last',
                               'acc': 'mean'}).reset_index()
df_res
# Out:
#                                       id                      model elayer  \
# 0                  Autoformer21mean250_1                 Autoformer      2
# 1                  Autoformer21mean250_2                 Autoformer      2
# 2                  Autoformer21mean500_1                 Autoformer      2
# 3                  Autoformer21mean500_2                 Autoformer      2
# 4                 Crossformer21mean250_1                Crossformer      2
# 5                 Crossformer21mean250_2                Crossformer      2
# 6                 Crossformer21mean500_1                Crossformer      2
# 7                 Crossformer21mean500_2                Crossformer      2
# 8                     DLinear21mean250_1                    DLinear      2
# 9                     DLinear21mean250_2                    DLinear      2
# 10                    DLinear21mean500_1                    DLinear      2
# 11                    DLinear21mean500_2                    DLinear      2
# 12                  FEDformer21mean250_1                  FEDformer      2
# 13                  FEDformer21mean250_2                  FEDformer      2
# 14                  FEDformer21mean500_1                  FEDformer      2
# 15                  FEDformer21mean500_2                  FEDformer      2
# 16                   Informer21mean250_1                   Informer      2
# 17                   Informer21mean250_2                   Informer      2
# 18                   Informer21mean500_1                   Informer      2
# 19                   Informer21mean500_2                   Informer      2
# 20  Nonstationary_Transformer21mean250_1  Nonstationary_Transformer      2
# 21  Nonstationary_Transformer21mean250_2  Nonstationary_Transformer      2
# 22  Nonstationary_Transformer21mean500_1  Nonstationary_Transformer      2
# 23  Nonstationary_Transformer21mean500_2  Nonstationary_Transformer      2
# 24                   PatchTST21mean250_1                   PatchTST      2
# 25                   PatchTST21mean250_2                   PatchTST      2
# 26                   PatchTST21mean500_1                   PatchTST      2
# 27                   PatchTST21mean500_2                   PatchTST      2
# 28                 Pyraformer21mean250_1                 Pyraformer      2
# 29                 Pyraformer21mean250_2                 Pyraformer      2
# 30                 Pyraformer21mean500_1                 Pyraformer      2
# 31                 Pyraformer21mean500_2                 Pyraformer      2
# 32                   Reformer21mean250_1                   Reformer      2
# 33                   Reformer21mean250_2                   Reformer      2
# 34                   Reformer21mean500_1                   Reformer      2
# 35                   Reformer21mean500_2                   Reformer      2
# 36                   TimesNet21mean250_1                   TimesNet      2
# 37                   TimesNet21mean250_2                   TimesNet      2
# 38                   TimesNet21mean500_1                   TimesNet      2
# 39                   TimesNet21mean500_2                   TimesNet      2
# 40                Transformer21mean250_1                Transformer      2
# 41                Transformer21mean250_2                Transformer      2
# 42                Transformer21mean500_1                Transformer      2
# 43                Transformer21mean500_2                Transformer      2
# 44                         bp21mean250_1                         bp      2
# 45                         bp21mean250_2                         bp      2
# 46                         bp21mean500_1                         bp      2
# 47                         bp21mean500_2                         bp      2
# 48                   conv_net21mean250_1                   conv_net      2
# 49                   conv_net21mean250_2                   conv_net      2
# 50                   conv_net21mean500_1                   conv_net      2
# 51                   conv_net21mean500_2                   conv_net      2
# 52                  conv_next21mean250_1                  conv_next      2
# 53                  conv_next21mean250_2                  conv_next      2
# 54                  conv_next21mean500_1                  conv_next      2
# 55                  conv_next21mean500_2                  conv_next      2
# 56                        fcn21mean250_1                        fcn      2
# 57                        fcn21mean250_2                        fcn      2
# 58                        fcn21mean500_1                        fcn      2
# 59                        fcn21mean500_2                        fcn      2
# 60                      fcn_m21mean250_1                      fcn_m      2
# 61                      fcn_m21mean250_2                      fcn_m      2
# 62                      fcn_m21mean500_1                      fcn_m      2
# 63                      fcn_m21mean500_2                      fcn_m      2
# 64                       lstm21mean250_1                       lstm      2
# 65                       lstm21mean250_2                       lstm      2
# 66                       lstm21mean500_1                       lstm      2
# 67                       lstm21mean500_2                       lstm      2
# 68                   lstm_fcn21mean250_1                   lstm_fcn      2
# 69                   lstm_fcn21mean250_2                   lstm_fcn      2
# 70                   lstm_fcn21mean500_1                   lstm_fcn      2
# 71                   lstm_fcn21mean500_2                   lstm_fcn      2
# 72                         my21mean250_1                         my      2
# 73                         my21mean250_2                         my      2
# 74                         my21mean500_1                         my      2
# 75                         my21mean500_2                         my      2
#
#    filter seq_len dlayer fc       acc
# 0    mean     250      1  1  0.409759
# 1    mean     250      1  2  0.410766
# 2    mean     500      1  1  0.407075
# 3    mean     500      1  2  0.394889
# 4    mean     250      1  1  0.606915
# 5    mean     250      1  2  0.648204
# 6    mean     500      1  1  0.640880
# 7    mean     500      1  2  0.657245
# 8    mean     250      1  1  0.637540
# 9    mean     250      1  2  0.637540
# 10   mean     500      1  1  0.630251
# 11   mean     500      1  2  0.630251
# 12   mean     250      1  1  0.465457
# 13   mean     250      1  2  0.464148
# 14   mean     500      1  1  0.417484
# 15   mean     500      1  2  0.417146
# 16   mean     250      1  1  0.676060
# 17   mean     250      1  2  0.678358
# 18   mean     500      1  1  0.714557
# 19   mean     500      1  2  0.710224
# 20   mean     250      1  1  0.628582
# 21   mean     250      1  2  0.628582
# 22   mean     500      1  1  0.659565
# 23   mean     500      1  2  0.659565
# 24   mean     250      1  1  0.369812
# 25   mean     250      1  2  0.369214
# 26   mean     500      1  1  0.354954
# 27   mean     500      1  2  0.352146
# 28   mean     250      1  1  0.663384
# 29   mean     250      1  2  0.663109
# 30   mean     500      1  1  0.681533
# 31   mean     500      1  2  0.678874
# 32   mean     250      1  1  0.687908
# 33   mean     250      1  2  0.687971
# 34   mean     500      1  1  0.694676
# 35   mean     500      1  2  0.702373
# 36   mean     250      1  1  0.675620
# 37   mean     250      1  2  0.678867
# 38   mean     500      1  1  0.679758
# 39   mean     500      1  2  0.679070
# 40   mean     250      1  1  0.689662
# 41   mean     250      1  2  0.689662
# 42   mean     500      1  1  0.696564
# 43   mean     500      1  2  0.696564
# 44   mean     250      1  1  0.687806
# 45   mean     250      1  2  0.687806
# 46   mean     500      1  1  0.690573
# 47   mean     500      1  2  0.690573
# 48   mean     250      1  1  0.685615
# 49   mean     250      1  2  0.685091
# 50   mean     500      1  1  0.703385
# 51   mean     500      1  2  0.703221
# 52   mean     250      1  1  0.657591
# 53   mean     250      1  2  0.657846
# 54   mean     500      1  1  0.657844
# 55   mean     500      1  2  0.659414
# 56   mean     250      1  1  0.683465
# 57   mean     250      1  2  0.683465
# 58   mean     500      1  1  0.700649
# 59   mean     500      1  2  0.700649
# 60   mean     250      1  1  0.681825
# 61   mean     250      1  2  0.681825
# 62   mean     500      1  1  0.684812
# 63   mean     500      1  2  0.684812
# 64   mean     250      1  1  0.660003
# 65   mean     250      1  2  0.660003
# 66   mean     500      1  1  0.685166
# 67   mean     500      1  2  0.685166
# 68   mean     250      1  1  0.692842
# 69   mean     250      1  2  0.692842
# 70   mean     500      1  1  0.682626
# 71   mean     500      1  2  0.682626
# 72   mean     250      1  1  0.659623
# 73   mean     250      1  2  0.670638
# 74   mean     500      1  1  0.686784
# 75   mean     500      1  2  0.696454

# %%
df_res['id'].iloc[0]
# Out:
# 'classification_bone_c_Autoformer_bone_drill_c_ftM_sl250_ll48_pl0_dm64_nh8_el2_dl1_df64_fc1_ebtimeF_dtTrue_Exp_mean'

# %%
df_res.to_excel('res.xlsx')

# %%
dff = df[-5::]
dff
# Out:
#     model elayer filter  iter       acc
# 140    my      2   mean     0  0.713115
# 141    my      2   mean     1  0.690265
# 142    my      2   mean     2  0.711864
# 143    my      2   mean     3  0.684685
# 144    my      2   mean     4  0.649123

# %%
dff['acc'].mean()
# Out:
# 0.6898104278611829

# %%
# 设置种子为当前时间戳
random.seed(0)

# %%
import random


# 生成随机整数
for i in range(5):
    random_number = random.randint(1, 100)
    print(random_number)
# Out:
# 56
# 41
# 79
# 82
# 27

# %%
3592042239
1736050280
3686380748
2704801039
2336936075

# %%
[1,2,3]+[1]
# Out:
# [1, 2, 3, 1]

# %%
a = [1,2,3,4,5]
a[0:0]
# Out:
# []

# %%
a[0:0]+[1]
# Out:
# [1]

# %% [markdown]
# - 250
# - 0.6780735811118614
# ![image.png](attachment:image.png)

# %% [markdown]
#  - 500
#  - 0.6940652338798191
#  - ![image.png](attachment:image.png)

# %% [markdown]
# - 1000
# - 0.7211055319220417
# ![image.png](attachment:image.png)

# %%
1000 0.7207143405426363
500 0.7030719195186041
250 0.6788877469978118
# Out:
# 0.6780735811118614

# %% [markdown]
# 250 0.699 使用12个，上面的都是使用6个时候
# 500 0.6898104278611829， 这个是使用部分数据集训练的
